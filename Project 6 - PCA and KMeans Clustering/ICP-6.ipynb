# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn import preprocessing 
import sklearn.cluster as cluster
from sklearn.cluster import KMeans 
from sklearn import metrics
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %% [markdown]
# # Q1

# %% [markdown]
# ##### Importing the house dataset and log scaling the SalePrice

# %%
train = pd.read_csv('houses_dataset.csv')
train.SalePrice = np.log(train.SalePrice)
train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# min       1.000000  1872.000000   1950.000000     0.000000     0.000000  ...
# 25%       5.000000  1954.000000   1967.000000     0.000000     0.000000  ...
# 50%       5.000000  1973.000000   1994.000000     0.000000   383.500000  ...
# 75%       6.000000  2000.000000   2004.000000   166.000000   712.250000  ...
# max       9.000000  2010.000000   2010.000000  1600.000000  5644.000000  ...
#
#         WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  ScreenPorch  \
# count  1460.000000  1460.000000    1460.000000  1460.000000  1460.000000
# mean     94.244521    46.660274      21.954110     3.409589    15.060959
# std     125.338794    66.256028      61.119149    29.317331    55.757415
# min       0.000000     0.000000       0.000000     0.000000     0.000000
# 25%       0.000000     0.000000       0.000000     0.000000     0.000000
# 50%       0.000000    25.000000       0.000000     0.000000     0.000000
# 75%     168.000000    68.000000       0.000000     0.000000     0.000000
# max     857.000000   547.000000     552.000000   508.000000   480.000000
#
#           PoolArea       MiscVal       MoSold       YrSold    SalePrice
# count  1460.000000   1460.000000  1460.000000  1460.000000  1460.000000
# mean      2.758904     43.489041     6.321918  2007.815753    12.024051
# std      40.177307    496.123024     2.703626     1.328095     0.399452
# min       0.000000      0.000000     1.000000  2006.000000    10.460242
# 25%       0.000000      0.000000     5.000000  2007.000000    11.775097
# 50%       0.000000      0.000000     6.000000  2008.000000    12.001505
# 75%       0.000000      0.000000     8.000000  2009.000000    12.273731
# max     738.000000  15500.000000    12.000000  2010.000000    13.534473
#
# [8 rows x 38 columns]

# %% [markdown]
# ##### Checking which values have a positive correlation with SalePrice

# %%
numeric_features = train.select_dtypes(include=[np.number])
corr = numeric_features.corr()
print("Positive Correlation:")
print(corr['SalePrice'].sort_values(ascending=False)[:], '\n')
print("\nNegative Correlation:")
print(corr['SalePrice'].sort_values(ascending=False)[-5:])
# Out:
# Positive Correlation:
# SalePrice        1.000000
# OverallQual      0.817184
# GrLivArea        0.700927
# GarageCars       0.680625
# GarageArea       0.650888
# TotalBsmtSF      0.612134
# 1stFlrSF         0.596981
# FullBath         0.594771
# YearBuilt        0.586570
# YearRemodAdd     0.565608
# GarageYrBlt      0.541073
# TotRmsAbvGrd     0.534422
# Fireplaces       0.489449
# MasVnrArea       0.430809
# BsmtFinSF1       0.372023
# LotFrontage      0.355878
# WoodDeckSF       0.334135
# OpenPorchSF      0.321053
# 2ndFlrSF         0.319300
# HalfBath         0.313982
# LotArea          0.257320
# BsmtFullBath     0.236224
# BsmtUnfSF        0.221985
# BedroomAbvGr     0.209044
# ScreenPorch      0.121208
# PoolArea         0.069798
# MoSold           0.057329
# 3SsnPorch        0.054900
# BsmtFinSF2       0.004832
# BsmtHalfBath    -0.005149
# Id              -0.017942
# MiscVal         -0.020021
# OverallCond     -0.036868
# YrSold          -0.037263
# LowQualFinSF    -0.037963
# MSSubClass      -0.073959
# KitchenAbvGr    -0.147548
# EnclosedPorch   -0.149050
# Name: SalePrice, dtype: float64
#
#
# Negative Correlation:
# YrSold          -0.037263
# LowQualFinSF    -0.037963
# MSSubClass      -0.073959
# KitchenAbvGr    -0.147548
# EnclosedPorch   -0.149050
# Name: SalePrice, dtype: float64

# %% [markdown]
# ##### Graphing the column with the highest correlation to SalePrice

# %%
ax1 = train.plot.scatter(x='OverallQual', y='SalePrice')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ##### Deleting a few outliers under the GarageArea

# %%
train.drop(train.loc[train['GarageArea']>=1230].index, inplace=True)

# %%
ax2 = train.plot.scatter(x='GarageArea', y='SalePrice')
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ##### Checking for Null Values

# %%
nulls = pd.DataFrame(train.isnull().sum().sort_values(ascending=False)[:5])
nulls.columns = ['Null Count']
nulls.index.name = 'Feature'
print(nulls)
# Out:
#              Null Count
# Feature
# PoolQC             1450
# MiscFeature        1403
# Alley              1365
# Fence              1175
# FireplaceQu         689

# %% [markdown]
# ##### Dropping/filling null values

# %%
data = train.select_dtypes(include=[np.number]).interpolate().dropna()
print(sum(data.isnull().sum() != 0))
# Out:
# 0

# %% [markdown]
# ##### No more nulls

# %%
nulls = pd.DataFrame(data.isnull().sum().sort_values(ascending=False)[:5])
nulls.columns = ['Null Count']
nulls.index.name = 'Feature'
print(nulls)
# Out:
#               Null Count
# Feature
# Id                     0
# WoodDeckSF             0
# BedroomAbvGr           0
# KitchenAbvGr           0
# TotRmsAbvGrd           0

# %% [markdown]
# ##### Setting the features and targets and running train test split

# %%
X = data['OverallQual'] 
y = data['SalePrice']

X = X.values.reshape(-1, 1)
y = y.values.reshape(-1, 1)

# %%
X_train_s, X_test_s,y_train_s, y_test_s = train_test_split(X,y,random_state=0,test_size=.2)

lr1 = linear_model.LinearRegression()
model_simple = lr1.fit(X_train_s,y_train_s)

y_pred_simple = model_simple.predict(X_test_s)

# %% [markdown]
# ##### Graphing the regression line

# %%
# Plot outputs
plt.figure(figsize=(8,8))
plt.scatter(X_test_s, y_test_s, color="black")
plt.plot(X_test_s, y_pred_simple, color="blue", linewidth=0.5)

plt.xticks(())
plt.yticks(())


plt.show()

# %% [markdown]
# ##### Setting the feature columns using 5 features this time and running train test split

# %%
X = data[['OverallQual', 'GrLivArea','GarageCars','GarageArea','TotalBsmtSF']]
y = data['SalePrice']

# %%
X
# Out:
#       OverallQual  GrLivArea  GarageCars  GarageArea  TotalBsmtSF
# 0               7       1710           2         548          856
# 1               6       1262           2         460         1262
# 2               7       1786           2         608          920
# 3               7       1717           3         642          756
# 4               8       2198           3         836         1145
# ...           ...        ...         ...         ...          ...
# 1455            6       1647           2         460          953
# 1456            6       2073           2         500         1542
# 1457            7       2340           1         252         1152
# 1458            5       1078           1         240         1078
# 1459            5       1256           1         276         1256
#
# [1456 rows x 5 columns]

# %%
X.shape
# Out:
# (1456, 5)

# %%
y
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
#           ...
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: SalePrice, Length: 1456, dtype: float64

# %%
y.shape
# Out:
# (1456,)

# %%
X_train_m, X_test_m,y_train_m, y_test_m = train_test_split(X,y,random_state=0,test_size=.2)

lr2 = linear_model.LinearRegression()
model_multi = lr2.fit(X_train_m,y_train_m)

y_pred_multi = model_multi.predict(X_test_m)

# %% [markdown]
# ##### Calculating the scores of the simple linear model and the multi linear model

# %%
print('score_simple:', model_simple.score(X_test_s,y_test_s))
print('score_multi:', model_multi.score(X_test_m,y_test_m))
# Out:
# score_simple: 0.7235509974309711
# score_multi: 0.8649862979577254

# %%
print('mse_simple:',mean_squared_error(y_test_s,y_pred_simple))
print('mse_multi:',mean_squared_error(y_test_m,y_pred_multi))
# Out:
# mse_simple: 0.04691463324610289
# mse_multi: 0.022912429618661065

# %%
print('rmse_simple:',mean_squared_error(y_test_s,y_pred_simple, squared = False))
print('rmse_multi:',mean_squared_error(y_test_m,y_pred_multi, squared = False))
# Out:
# rmse_simple: 0.2165978606683429
# rmse_multi: 0.15136852254898

# %%
print('mae_simple:',mean_absolute_error(y_test_s,y_pred_simple))
print('mae_multi:',mean_absolute_error(y_test_m,y_pred_multi))
# Out:
# mae_simple: 0.1674090087441477
# mae_multi: 0.11651925672932993

# %%
print('r2_simple:',r2_score(y_test_s,y_pred_simple))
print('r2_multi:',r2_score(y_test_m,y_pred_multi))
# Out:
# r2_simple: 0.7235509974309711
# r2_multi: 0.8649862979577254

# %% [markdown]
# ##### Setting up another test with standard scaler

# %%
X = data.drop('SalePrice', axis = 1)
y = np.log(data.SalePrice)

# %%
X = StandardScaler().fit_transform(X)

# %% [markdown]
# ##### Setting up PCA method

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents, columns = ['PCA_1', 'PCA_2'])

# %%
X_train_PCA, X_test_PCA,y_train_PCA, y_test_PCA = train_test_split(X,y,random_state=0,test_size=.2)

# %%
lr3 = linear_model.LinearRegression()
model_PCA = lr3.fit(X_train_PCA,y_train_PCA)

y_pred_PCA = model_PCA.predict(X_test_PCA)

# %% [markdown]
# ##### Calculating model scores after using PCA method

# %%
print('score_simple:', model_simple.score(X_test_s,y_test_s))
print('mse_simple:',mean_squared_error(y_test_s,y_pred_simple))
print('rmse_simple:',mean_squared_error(y_test_s,y_pred_simple, squared = False))
print('mae_simple:',mean_absolute_error(y_test_s,y_pred_simple))
print('r2_simple:',r2_score(y_test_s,y_pred_simple))
# Out:
# score_simple: 0.7235509974309711
# mse_simple: 0.04691463324610289
# rmse_simple: 0.2165978606683429
# mae_simple: 0.1674090087441477
# r2_simple: 0.7235509974309711

# %%
print('score_multi:', model_multi.score(X_test_m,y_test_m))
print('mse_multi:',mean_squared_error(y_test_m,y_pred_multi))
print('rmse_multi:',mean_squared_error(y_test_m,y_pred_multi, squared = False))
print('mae_multi:',mean_absolute_error(y_test_m,y_pred_multi))
print('r2_multi:',r2_score(y_test_m,y_pred_multi))
# Out:
# score_multi: 0.8649862979577254
# mse_multi: 0.022912429618661065
# rmse_multi: 0.15136852254898
# mae_multi: 0.11651925672932993
# r2_multi: 0.8649862979577254

# %%
print('score_PCA:', model_PCA.score(X_test_PCA,y_test_PCA))
print('mse_PCA:',mean_squared_error(y_test_PCA,y_pred_PCA))
print('rmse_PCA:',mean_squared_error(y_test_PCA,y_pred_PCA, squared = False))
print('mae_PCA:',mean_absolute_error(y_test_PCA,y_pred_PCA))
print('r2_PCA:',r2_score(y_test_PCA,y_pred_PCA))
# Out:
# score_PCA: 0.9156456939387201
# mse_PCA: 9.786441828962521e-05
# rmse_PCA: 0.00989264465598685
# mae_PCA: 0.007461278312875494
# r2_PCA: 0.9156456939387201

# %% [markdown]
# # Q2

# %% [markdown]
# ##### Importing credit card data and dropping the Customer ID column

# %%
credit_df = pd.read_csv('credit card.csv')
credit_df.drop('CUST_ID', axis = 1, inplace = True)

credit_df
# Out:
#           BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0       40.900749           0.818182      95.40              0.00
# 1     3202.467416           0.909091       0.00              0.00
# 2     2495.148862           1.000000     773.17            773.17
# 3     1666.670542           0.636364    1499.00           1499.00
# 4      817.714335           1.000000      16.00             16.00
# ...           ...                ...        ...               ...
# 8945    28.493517           1.000000     291.12              0.00
# 8946    19.183215           1.000000     300.00              0.00
# 8947    23.398673           0.833333     144.40              0.00
# 8948    13.457564           0.833333       0.00              0.00
# 8949   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                       0.000000                          0.083333
# 1                       0.000000                          0.000000
# 2                       1.000000                          0.000000
# 3                       0.083333                          0.000000
# 4                       0.083333                          0.000000
# ...                          ...                               ...
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                   0.000000                 0              2        1000.0
# 1                   0.250000                 4              0        7000.0
# 2                   0.000000                 0             12        7500.0
# 3                   0.083333                 1              1        7500.0
# 4                   0.000000                 0              1        1200.0
# ...                      ...               ...            ...           ...
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#          PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0      201.802084        139.509787          0.000000      12
# 1     4103.032597       1072.340217          0.222222      12
# 2      622.066742        627.284787          0.000000      12
# 3        0.000000               NaN          0.000000      12
# 4      678.334763        244.791237          0.000000      12
# ...           ...               ...               ...     ...
# 8945   325.594462         48.886365          0.500000       6
# 8946   275.861322               NaN          0.000000       6
# 8947    81.270775         82.418369          0.250000       6
# 8948    52.549959         55.755628          0.250000       6
# 8949    63.165404         88.288956          0.000000       6
#
# [8950 rows x 17 columns]

# %% [markdown]
# ##### Checking for Null Values

# %%
nulls = pd.DataFrame(credit_df.isnull().sum().sort_values(ascending=False)[:5])
nulls.columns = ['Null Count']
nulls.index.name = 'Feature'
print(nulls)
# Out:
#                         Null Count
# Feature
# MINIMUM_PAYMENTS               313
# CREDIT_LIMIT                     1
# BALANCE                          0
# CASH_ADVANCE_FREQUENCY           0
# PRC_FULL_PAYMENT                 0

# %% [markdown]
# ##### Filling null values with the mean

# %%
column_means = credit_df.mean(numeric_only=True)
credit_df = credit_df.fillna(column_means)

# %%
nulls = pd.DataFrame(credit_df.isnull().sum().sort_values(ascending=False)[:5])
nulls.columns = ['Null Count']
nulls.index.name = 'Feature'
print(nulls)
# Out:
#                         Null Count
# Feature
# BALANCE                          0
# CASH_ADVANCE_FREQUENCY           0
# PRC_FULL_PAYMENT                 0
# MINIMUM_PAYMENTS                 0
# PAYMENTS                         0

# %% [markdown]
# ##### Calculating the sum of squared distance for various clusters

# %%
wcss=[]

for i in range(1,18):
    kmeans = KMeans(i)
    kmeans.fit(credit_df)
    wcss_iter = kmeans.inertia_
    wcss.append(wcss_iter)

# %% [markdown]
# ##### Plotting the graph and using elbow method to figure out good value for k means

# %%
clusters = range(1,18)
plt.plot(clusters,wcss)
plt.xlabel("Clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# ##### Setting the amount of clusters

# %%
nclusters = 2
km = KMeans(n_clusters=nclusters, random_state=0) 
km.fit(credit_df)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
y_cluster_kmeans = km.predict(credit_df)
score = metrics.silhouette_score(credit_df, y_cluster_kmeans)

# %% [markdown]
# ##### Verifying the elbow method with silhouette score

# %%
for i in range(2,18):
    labels=cluster.KMeans(n_clusters=i,init="k-means++",random_state=200).fit(credit_df).labels_
    print ("k = "+str(i)+" is "
           +str(metrics.silhouette_score(credit_df,labels,metric="euclidean",sample_size=1000,random_state=200)))
# Out:
# k = 2 is 0.5128066305677381
# k = 3 is 0.45913031286895445
# k = 4 is 0.38102444549500764
# k = 5 is 0.3766624921843038
# k = 6 is 0.37800822183700056
# k = 7 is 0.3531402241100118
# k = 8 is 0.35959487533502044
# k = 9 is 0.3405452070757967
# k = 10 is 0.3509244508886415
# k = 11 is 0.35261193014004893
# k = 12 is 0.36101189968816144
# k = 13 is 0.2995049646494924
# k = 14 is 0.28224987602583906
# k = 15 is 0.283343275213908
# k = 16 is 0.256114568226038
# k = 17 is 0.281301101242947

# %% [markdown]
# ##### Adding the cluster as another column to the dataset

# %%
credit_df['Clusters'] = km.labels_

# %% [markdown]
# ##### Printing the graph and visuailze the clusters

# %%
sns.set(rc={'figure.figsize':(15,15)})
sns.scatterplot(x = credit_df['BALANCE'],y = credit_df['PURCHASES'],hue=credit_df['Clusters'],palette='Set1')
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='PURCHASES'>

# %% [markdown]
# ##### Attempting another try using standard scaler

# %%
credit_df.drop('Clusters', axis = 1, inplace = True)

scaler = preprocessing.StandardScaler() 
scaler.fit(credit_df) 
X_scaled_array = scaler.transform(credit_df)
credit_df_scaled = pd.DataFrame(X_scaled_array, columns = credit_df.columns)

# %%
credit_df_scaled
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    -0.731989          -0.249434  -0.424900         -0.356934
# 1     0.786961           0.134325  -0.469552         -0.356934
# 2     0.447135           0.518084  -0.107668          0.108889
# 3     0.049099          -1.016953   0.232058          0.546189
# 4    -0.358775           0.518084  -0.462063         -0.347294
# ...        ...                ...        ...               ...
# 8945 -0.737950           0.518084  -0.333293         -0.356934
# 8946 -0.742423           0.518084  -0.329136         -0.356934
# 8947 -0.740398          -0.185477  -0.401965         -0.356934
# 8948 -0.745174          -0.185477  -0.469552         -0.356934
# 8949 -0.572575          -0.889033   0.042146          0.301732
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                  -0.349079     -0.466786            -0.806490
# 1                  -0.454576      2.605605            -1.221758
# 2                  -0.454576     -0.466786             1.269843
# 3                  -0.454576     -0.368653            -1.014125
# 4                  -0.454576     -0.466786            -1.014125
# ...                      ...           ...                  ...
# 8945               -0.132643     -0.466786             1.269843
# 8946               -0.122823     -0.466786             1.269843
# 8947               -0.294893     -0.466786             0.854576
# 8948               -0.454576     -0.449352            -1.221758
# 8949               -0.454576     -0.406205             0.439310
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                      -0.678661                         -0.707313
# 1                      -0.678661                         -0.916995
# 2                       2.673451                         -0.916995
# 3                      -0.399319                         -0.916995
# 4                      -0.399319                         -0.916995
# ...                          ...                               ...
# 8945                   -0.678661                          1.179833
# 8946                   -0.678661                          1.179833
# 8947                   -0.678661                          0.760469
# 8948                   -0.678661                         -0.916995
# 8949                    1.556082                         -0.916995
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                  -0.675349         -0.476070      -0.511333     -0.960433
# 1                   0.573963          0.110074      -0.591796      0.688639
# 2                  -0.675349         -0.476070      -0.109020      0.826062
# 3                  -0.258913         -0.329534      -0.551565      0.826062
# 4                  -0.675349         -0.476070      -0.551565     -0.905464
# ...                      ...               ...            ...           ...
# 8945               -0.675349         -0.476070      -0.350408     -0.960433
# 8946               -0.675349         -0.476070      -0.350408     -0.960433
# 8947               -0.675349         -0.476070      -0.390639     -0.960433
# 8948                0.157527         -0.182998      -0.591796     -1.097856
# 8949                0.990398         -0.182998       0.333524     -0.905464
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# 0    -0.528979     -3.109675e-01         -0.525551  0.360680
# 1     0.818642      8.931021e-02          0.234227  0.360680
# 2    -0.383805     -1.016632e-01         -0.525551  0.360680
# 3    -0.598688      4.878305e-17         -0.525551  0.360680
# 4    -0.364368     -2.657913e-01         -0.525551  0.360680
# ...        ...               ...               ...       ...
# 8945 -0.486217     -3.498541e-01          1.183951 -4.122768
# 8946 -0.503396      4.878305e-17         -0.525551 -4.122768
# 8947 -0.570615     -3.354655e-01          0.329200 -4.122768
# 8948 -0.580536     -3.469065e-01          0.329200 -4.122768
# 8949 -0.576869     -3.329464e-01         -0.525551 -4.122768
#
# [8950 rows x 17 columns]

# %% [markdown]
# ##### Recalculate the sum of sqaured distance scores

# %%
wcss_scaled=[]

for i in range(1,18):
    kmeans = KMeans(i)
    kmeans.fit(credit_df_scaled)
    wcss_iter = kmeans.inertia_
    wcss_scaled.append(wcss_iter)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Tigran\Documents\Semester8\CS490\ICP-6\ICP-6.ipynb Cell 72' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Tigran/Documents/Semester8/CS490/ICP-6/ICP-6.ipynb#ch0000067?line=2'>3</a> for i in range(1,18):
#       <a href='vscode-notebook-cell:/c%3A/Users/Tigran/Documents/Semester8/CS490/ICP-6/ICP-6.ipynb#ch0000067?line=3'>4</a>     kmeans = KMeans(i)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tigran/Documents/Semester8/CS490/ICP-6/ICP-6.ipynb#ch0000067?line=4'>5</a>     kmeans.fit(credit_df_scaled)
#       <a href='vscode-notebook-cell:/c%3A/Users/Tigran/Documents/Semester8/CS490/ICP-6/ICP-6.ipynb#ch0000067?line=5'>6</a>     wcss_iter = kmeans.inertia_
#       <a href='vscode-notebook-cell:/c%3A/Users/Tigran/Documents/Semester8/CS490/ICP-6/ICP-6.ipynb#ch0000067?line=6'>7</a>     wcss_scaled.append(wcss_iter)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1189, in KMeans.fit(self, X, y, sample_weight)
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1185'>1186</a>     print("Initialization complete")
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1187'>1188</a> # run a k-means once
# -> <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1188'>1189</a> labels, inertia, centers, n_iter_ = kmeans_single(
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1189'>1190</a>     X,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1190'>1191</a>     sample_weight,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1191'>1192</a>     centers_init,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1192'>1193</a>     max_iter=self.max_iter,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1193'>1194</a>     verbose=self.verbose,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1194'>1195</a>     tol=self._tol,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1195'>1196</a>     x_squared_norms=x_squared_norms,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1196'>1197</a>     n_threads=self._n_threads,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1197'>1198</a> )
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1199'>1200</a> # determine if these results are the best so far
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1200'>1201</a> # we chose a new run if it has a better inertia and the clustering is
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1201'>1202</a> # different from the best so far (it's possible that the inertia is
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1202'>1203</a> # slightly better even if the clustering is the same with potentially
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1203'>1204</a> # permuted labels, due to rounding errors)
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1204'>1205</a> if best_inertia is None or (
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1205'>1206</a>     inertia < best_inertia
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1206'>1207</a>     and not _is_same_clustering(labels, best_labels, self.n_clusters)
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1207'>1208</a> ):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:495, in _kmeans_single_elkan(X, sample_weight, centers_init, max_iter, verbose, x_squared_norms, tol, n_threads)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=491'>492</a> # compute new pairwise distances between centers and closest other
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=492'>493</a> # center of each center for next iterations
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=493'>494</a> center_half_distances = euclidean_distances(centers_new) / 2
# --> <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=494'>495</a> distance_next_center = np.partition(
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=495'>496</a>     np.asarray(center_half_distances), kth=1, axis=0
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=496'>497</a> )[1]
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=498'>499</a> if verbose:
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=499'>500</a>     inertia = _inertia(X, sample_weight, centers, labels, n_threads)
#
# File <__array_function__ internals>:5, in partition(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:748, in partition(a, kth, axis, kind, order)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/numpy/core/fromnumeric.py?line=745'>746</a> else:
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/numpy/core/fromnumeric.py?line=746'>747</a>     a = asanyarray(a).copy(order="K")
# --> <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/numpy/core/fromnumeric.py?line=747'>748</a> a.partition(kth, axis=axis, kind=kind, order=order)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/numpy/core/fromnumeric.py?line=748'>749</a> return a
#
# KeyboardInterrupt:

# %%
clusters = range(1,18)
plt.plot(clusters,wcss)
plt.xlabel("Clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# ##### Set the amount of clusters

# %%
nclusters_scaled = 3
km_scaled = KMeans(n_clusters=nclusters_scaled, random_state=0) 
km_scaled.fit(credit_df_scaled)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
y_cluster_kmeans_scaled = km_scaled.predict(credit_df_scaled)
score_scaled = metrics.silhouette_score(credit_df_scaled, y_cluster_kmeans_scaled)

# %% [markdown]
# ##### Verify with silhouette score

# %%
for i in range(2,18):
    labels=cluster.KMeans(n_clusters=i,init="k-means++",random_state=200).fit(credit_df_scaled).labels_
    print ("k = "+str(i)+" is "
           +str(metrics.silhouette_score(credit_df_scaled,labels,metric="euclidean",sample_size=1000,random_state=200)))
# Out:
# k = 2 is 0.2207297619903141
# k = 3 is 0.2550341055038475
# k = 4 is 0.20709423340906297
# k = 5 is 0.20870492276672542
# k = 6 is 0.21255075340318852
# k = 7 is 0.21430087673617573
# k = 8 is 0.22586953077752203
# k = 9 is 0.22276677166382547
# k = 10 is 0.22881420529158264
# k = 11 is 0.22356794921361273
# k = 12 is 0.22038045034012277
# k = 13 is 0.2254666863594262
# k = 14 is 0.19315944748029146
# k = 15 is 0.22291098059295808
# k = 16 is 0.18375754337802813
# k = 17 is 0.19079546796301838

# %% [markdown]
# ##### Adding the cluster columns and print the graph

# %%
credit_df_scaled['Clusters'] = km_scaled.labels_

# %%
sns.scatterplot(x = credit_df_scaled['BALANCE'],y = credit_df_scaled['PURCHASES'],hue=credit_df_scaled['Clusters'],palette='Set1')
# Out:
# <AxesSubplot:xlabel='BALANCE', ylabel='PURCHASES'>

# %% [markdown]
# ##### One more try using PCA method

# %%
credit_df_PCA = StandardScaler().fit_transform(credit_df)

# %%
pca = PCA(n_components=2)   
prinComp = pca.fit_transform(credit_df_PCA)
princeDf = pd.DataFrame(data = prinComp,columns=['PCA_1','PCA_2'])

# %% [markdown]
# ##### Calculate clusters again

# %%
wcss_PCA=[]

for i in range(1,18):
    kmeans_PCA = KMeans(i)
    kmeans_PCA.fit(princeDf)
    wcss_iter = kmeans.inertia_
    wcss_PCA.append(wcss_iter)

# %%
clusters = range(1,18)
plt.plot(clusters,wcss)
plt.xlabel("Clusters")
plt.ylabel("WCSS")
# Out:
# Text(0, 0.5, 'WCSS')

# %% [markdown]
# ##### Set clusters

# %%
nclusters_PCA = 2
km_PCA = KMeans(n_clusters=nclusters_PCA, random_state=0) 
km_PCA.fit(princeDf)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
y_cluster_kmeans_PCA = km_PCA.predict(princeDf)
score_PCA = metrics.silhouette_score(princeDf, y_cluster_kmeans_PCA)
score_PCA
# Out:
# 0.4647554203198954

# %% [markdown]
# ##### Verify

# %%
for i in range(2,18):
    labels=cluster.KMeans(n_clusters=i,init="k-means++",random_state=200).fit(princeDf).labels_
    print ("k = "+str(i)+" is "
           +str(metrics.silhouette_score(princeDf,labels,metric="euclidean",sample_size=1000,random_state=200)))
# Out:
# k = 2 is 0.46656358405555637
# k = 3 is 0.4432257872393676
# k = 4 is 0.41459282947655374
# k = 5 is 0.4101211960664973
# k = 6 is 0.37335799067967923
# k = 7 is 0.37094244264417314
# k = 8 is 0.382044440562333
# k = 9 is 0.3714460827784769
# k = 10 is 0.3672866856169601
# k = 11 is 0.37435515657529145
# k = 12 is 0.3742593231476211
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Tigran\Documents\Semester8\CS490\ICP-6\ICP-6.ipynb Cell 92' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Tigran/Documents/Semester8/CS490/ICP-6/ICP-6.ipynb#ch0000087?line=0'>1</a> for i in range(2,18):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Tigran/Documents/Semester8/CS490/ICP-6/ICP-6.ipynb#ch0000087?line=1'>2</a>     labels=cluster.KMeans(n_clusters=i,init="k-means++",random_state=200).fit(princeDf).labels_
#       <a href='vscode-notebook-cell:/c%3A/Users/Tigran/Documents/Semester8/CS490/ICP-6/ICP-6.ipynb#ch0000087?line=2'>3</a>     print ("k = "+str(i)+" is "
#       <a href='vscode-notebook-cell:/c%3A/Users/Tigran/Documents/Semester8/CS490/ICP-6/ICP-6.ipynb#ch0000087?line=3'>4</a>            +str(metrics.silhouette_score(princeDf,labels,metric="euclidean",sample_size=1000,random_state=200)))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:1189, in KMeans.fit(self, X, y, sample_weight)
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1185'>1186</a>     print("Initialization complete")
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1187'>1188</a> # run a k-means once
# -> <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1188'>1189</a> labels, inertia, centers, n_iter_ = kmeans_single(
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1189'>1190</a>     X,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1190'>1191</a>     sample_weight,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1191'>1192</a>     centers_init,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1192'>1193</a>     max_iter=self.max_iter,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1193'>1194</a>     verbose=self.verbose,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1194'>1195</a>     tol=self._tol,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1195'>1196</a>     x_squared_norms=x_squared_norms,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1196'>1197</a>     n_threads=self._n_threads,
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1197'>1198</a> )
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1199'>1200</a> # determine if these results are the best so far
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1200'>1201</a> # we chose a new run if it has a better inertia and the clustering is
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1201'>1202</a> # different from the best so far (it's possible that the inertia is
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1202'>1203</a> # slightly better even if the clustering is the same with potentially
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1203'>1204</a> # permuted labels, due to rounding errors)
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1204'>1205</a> if best_inertia is None or (
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1205'>1206</a>     inertia < best_inertia
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1206'>1207</a>     and not _is_same_clustering(labels, best_labels, self.n_clusters)
#    <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=1207'>1208</a> ):
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\cluster\_kmeans.py:526, in _kmeans_single_elkan(X, sample_weight, centers_init, max_iter, verbose, x_squared_norms, tol, n_threads)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=521'>522</a>     labels_old[:] = labels
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=523'>524</a> if not strict_convergence:
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=524'>525</a>     # rerun E-step so that predicted labels match cluster centers
# --> <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=525'>526</a>     elkan_iter(
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=526'>527</a>         X,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=527'>528</a>         sample_weight,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=528'>529</a>         centers,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=529'>530</a>         centers,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=530'>531</a>         weight_in_clusters,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=531'>532</a>         center_half_distances,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=532'>533</a>         distance_next_center,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=533'>534</a>         upper_bounds,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=534'>535</a>         lower_bounds,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=535'>536</a>         labels,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=536'>537</a>         center_shift,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=537'>538</a>         n_threads,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=538'>539</a>         update_centers=False,
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=539'>540</a>     )
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=541'>542</a> inertia = _inertia(X, sample_weight, centers, labels, n_threads)
#     <a href='file:///~/AppData/Local/Programs/Python/Python39/lib/site-packages/sklearn/cluster/_kmeans.py?line=543'>544</a> return labels, inertia, centers, i + 1
#
# KeyboardInterrupt:

# %% [markdown]
# ##### Add label and print graph

# %%
princeDf['Clusters'] = km_PCA.labels_

# %%
sns.scatterplot(x = princeDf['PCA_1'],y = princeDf['PCA_2'],hue=princeDf['Clusters'],palette='Set1')
# Out:
# <AxesSubplot:xlabel='PCA_1', ylabel='PCA_2'>
