# %%
from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC, LinearSVC
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests
import nltk
from nltk import word_tokenize
from nltk import PorterStemmer, LancasterStemmer, SnowballStemmer, WordNetLemmatizer
from nltk import wordpunct_tokenize, pos_tag, ne_chunk
from nltk.corpus import stopwords
from nltk import everygrams
from nltk import ngrams
from collections import Counter
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Q1

# %% [markdown]
# #### Transforming 20 newsgroup dataset with tf–idf vectorizer and Running MultinomialNB, SVM/svc, and KNN classification algorithms on the dataset.
#
# ##### Results:
# ##### MNB: 0.77
# ##### SVM: 0.84
# ##### KNN: 0.66

# %%
twenty_train = fetch_20newsgroups(subset='train', shuffle=True)
twenty_test = fetch_20newsgroups(subset='test', shuffle=True)

# tfidf vectorizer
tfidf_Vect = TfidfVectorizer()

# xtrain,xtest split
X_train_tfidf = tfidf_Vect.fit_transform(twenty_train.data)
X_test_tfidf = tfidf_Vect.transform(twenty_test.data)

# %%
# Multinomial NB fit
clf = MultinomialNB()
clf.fit(X_train_tfidf, twenty_train.target)

#Printing accuracy on predictions
predicted = clf.predict(X_test_tfidf)
score = metrics.accuracy_score(twenty_test.target, predicted)
print(score)
# Out:
# 0.7738980350504514

# %%
# SVC fit
classifier = svm.SVC(kernel='linear', gamma='auto',C=2)
classifier.fit(X_train_tfidf,twenty_train.target)

#Printing accuracy on predictions
y_predict = classifier.predict(X_test_tfidf)
print(classification_report(twenty_test.target,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.75      0.80       319
#            1       0.69      0.83      0.75       389
#            2       0.77      0.70      0.73       394
#            3       0.69      0.79      0.74       392
#            4       0.82      0.83      0.83       385
#            5       0.84      0.73      0.78       395
#            6       0.81      0.91      0.86       390
#            7       0.87      0.89      0.88       396
#            8       0.97      0.93      0.95       398
#            9       0.91      0.93      0.92       397
#           10       0.97      0.94      0.96       399
#           11       0.96      0.89      0.92       396
#           12       0.75      0.81      0.78       393
#           13       0.86      0.84      0.85       396
#           14       0.92      0.89      0.91       394
#           15       0.85      0.92      0.88       398
#           16       0.75      0.89      0.81       364
#           17       0.98      0.86      0.92       376
#           18       0.75      0.59      0.66       310
#           19       0.73      0.65      0.69       251
#
#     accuracy                           0.84      7532
#    macro avg       0.84      0.83      0.83      7532
# weighted avg       0.84      0.84      0.84      7532

# %%
# KNN fit with k = 3
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train_tfidf, twenty_train.target)

#Printing accuracy on predictions
Y_pred = knn.predict(X_test_tfidf)
print(classification_report(twenty_test.target,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.43      0.75      0.54       319
#            1       0.45      0.65      0.53       389
#            2       0.52      0.56      0.54       394
#            3       0.52      0.62      0.57       392
#            4       0.55      0.58      0.56       385
#            5       0.69      0.59      0.64       395
#            6       0.59      0.48      0.53       390
#            7       0.75      0.68      0.71       396
#            8       0.83      0.80      0.82       398
#            9       0.77      0.75      0.76       397
#           10       0.88      0.82      0.85       399
#           11       0.74      0.83      0.78       396
#           12       0.72      0.47      0.57       393
#           13       0.78      0.51      0.62       396
#           14       0.81      0.77      0.79       394
#           15       0.80      0.72      0.76       398
#           16       0.72      0.72      0.72       364
#           17       0.70      0.72      0.71       376
#           18       0.60      0.56      0.58       310
#           19       0.62      0.51      0.56       251
#
#     accuracy                           0.66      7532
#    macro avg       0.67      0.65      0.66      7532
# weighted avg       0.68      0.66      0.66      7532

# %% [markdown]
# #### Transforming 20 newsgroup dataset with tf–idf vectorizer with Bigrams and Running MultinomialNB, SVM/svc, and KNN algorithms again.
#
# ##### Results:
# ##### MNB: 0.73
# ##### SVM: 0.78
# ##### KNN: 0.59

# %%
# tfidf vectorizer with bigrams = 2
tfidf_Vect = TfidfVectorizer(ngram_range=(2,2))

# xtrain,xtest split
X_train_tfidf = tfidf_Vect.fit_transform(twenty_train.data)
X_test_tfidf = tfidf_Vect.transform(twenty_test.data)

# %%
# Multinomial NB fit
clf = MultinomialNB()
clf.fit(X_train_tfidf, twenty_train.target)

#Printing accuracy on predictions
predicted = clf.predict(X_test_tfidf)
score = metrics.accuracy_score(twenty_test.target, predicted)
print(score)
# Out:
# 0.7327403080191184

# %%
# SVC fit
classifier = svm.SVC(kernel='linear', gamma='auto',C=2)
classifier.fit(X_train_tfidf,twenty_train.target)

#Printing accuracy on predictions
y_predict = classifier.predict(X_test_tfidf)
print(classification_report(twenty_test.target,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.81       319
#            1       0.49      0.74      0.59       389
#            2       0.74      0.62      0.68       394
#            3       0.57      0.72      0.64       392
#            4       0.74      0.74      0.74       385
#            5       0.72      0.68      0.70       395
#            6       0.80      0.88      0.84       390
#            7       0.80      0.81      0.80       396
#            8       0.92      0.88      0.90       398
#            9       0.86      0.88      0.87       397
#           10       0.92      0.90      0.91       399
#           11       0.94      0.85      0.89       396
#           12       0.67      0.70      0.68       393
#           13       0.82      0.65      0.73       396
#           14       0.88      0.84      0.86       394
#           15       0.78      0.92      0.84       398
#           16       0.78      0.86      0.81       364
#           17       0.97      0.79      0.87       376
#           18       0.82      0.63      0.71       310
#           19       0.80      0.60      0.69       251
#
#     accuracy                           0.78      7532
#    macro avg       0.79      0.77      0.78      7532
# weighted avg       0.79      0.78      0.78      7532

# %%
# KNN fit with k = 3
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train_tfidf, twenty_train.target)

#Printing accuracy on predictions
Y_pred = knn.predict(X_test_tfidf)
print(classification_report(twenty_test.target,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.78      0.65       319
#            1       0.31      0.54      0.39       389
#            2       0.34      0.44      0.38       394
#            3       0.38      0.49      0.43       392
#            4       0.42      0.48      0.45       385
#            5       0.54      0.46      0.50       395
#            6       0.47      0.45      0.46       390
#            7       0.64      0.56      0.60       396
#            8       0.76      0.80      0.78       398
#            9       0.68      0.61      0.64       397
#           10       0.76      0.72      0.74       399
#           11       0.77      0.77      0.77       396
#           12       0.64      0.48      0.55       393
#           13       0.70      0.43      0.53       396
#           14       0.75      0.74      0.74       394
#           15       0.89      0.66      0.76       398
#           16       0.79      0.68      0.73       364
#           17       0.81      0.68      0.74       376
#           18       0.72      0.59      0.65       310
#           19       0.63      0.54      0.58       251
#
#     accuracy                           0.59      7532
#    macro avg       0.63      0.60      0.60      7532
# weighted avg       0.63      0.59      0.60      7532

# %% [markdown]
# #### Transforming 20 newsgroup dataset with tf–idf vectorizer with stop words set to english and Running MultinomialNB, SVM/svc, and KNN algorithms one last time.
#
# ##### Results:
# ##### MNB: 0.82
# ##### SVM: 0.84
# ##### KNN: 0.67

# %%
# tfidf vectorizer with stop words = english
tfidf_Vect = TfidfVectorizer(stop_words='english')

# xtrain,xtest split
X_train_tfidf = tfidf_Vect.fit_transform(twenty_train.data)
X_test_tfidf = tfidf_Vect.transform(twenty_test.data)

# %%
# Multinomial NB fit
clf = MultinomialNB()
clf.fit(X_train_tfidf, twenty_train.target)

#Printing accuracy on predictions
predicted = clf.predict(X_test_tfidf)
score = metrics.accuracy_score(twenty_test.target, predicted)
print(score)
# Out:
# 0.8169144981412639

# %%
# SVC fit
classifier = svm.SVC(kernel='linear', gamma='auto',C=2)
classifier.fit(X_train_tfidf,twenty_train.target)

#Printing accuracy on predictions
y_predict = classifier.predict(X_test_tfidf)
print(classification_report(twenty_test.target,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.74      0.79       319
#            1       0.68      0.81      0.74       389
#            2       0.78      0.71      0.75       394
#            3       0.69      0.79      0.73       392
#            4       0.83      0.83      0.83       385
#            5       0.83      0.74      0.78       395
#            6       0.78      0.90      0.84       390
#            7       0.90      0.89      0.89       396
#            8       0.96      0.94      0.95       398
#            9       0.90      0.93      0.92       397
#           10       0.97      0.95      0.96       399
#           11       0.96      0.89      0.92       396
#           12       0.73      0.81      0.77       393
#           13       0.87      0.84      0.86       396
#           14       0.92      0.90      0.91       394
#           15       0.86      0.91      0.88       398
#           16       0.76      0.89      0.82       364
#           17       0.99      0.85      0.91       376
#           18       0.79      0.60      0.68       310
#           19       0.71      0.65      0.68       251
#
#     accuracy                           0.84      7532
#    macro avg       0.84      0.83      0.83      7532
# weighted avg       0.84      0.84      0.84      7532

# %%
# KNN fit with k = 3
knn = KNeighborsClassifier(n_neighbors = 3)
knn.fit(X_train_tfidf, twenty_train.target)

#Printing accuracy on predictions
Y_pred = knn.predict(X_test_tfidf)
print(classification_report(twenty_test.target,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.73      0.65       319
#            1       0.41      0.66      0.51       389
#            2       0.46      0.58      0.52       394
#            3       0.47      0.62      0.53       392
#            4       0.53      0.59      0.56       385
#            5       0.64      0.55      0.59       395
#            6       0.52      0.48      0.50       390
#            7       0.70      0.67      0.69       396
#            8       0.82      0.83      0.83       398
#            9       0.76      0.74      0.75       397
#           10       0.84      0.84      0.84       399
#           11       0.81      0.82      0.81       396
#           12       0.71      0.52      0.60       393
#           13       0.79      0.56      0.65       396
#           14       0.79      0.79      0.79       394
#           15       0.85      0.75      0.80       398
#           16       0.77      0.70      0.73       364
#           17       0.88      0.72      0.79       376
#           18       0.80      0.58      0.67       310
#           19       0.64      0.55      0.59       251
#
#     accuracy                           0.67      7532
#    macro avg       0.69      0.66      0.67      7532
# weighted avg       0.69      0.67      0.67      7532

# %% [markdown]
# # Q2

# %%
#requesting the target website and storing it
html = requests.get('https://www.storynory.com/fox-and-the-crow/')

#calling beautifulsoup html parser for the requested website
bs = BeautifulSoup(html.content, 'html.parser')

# %%
#storing all parapgraphs into page which is now a list of 11 paragraphs
page = bs.find_all('p')

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('maxent_ne_chunker')
nltk.download('words')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Tigran\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Tigran\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Tigran\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Tigran\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\Tigran\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Tigran\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Tigran\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#creating a small subset of paragraphs to run some of the algorithms on
text = page[6].string + page[7].string

# %% [markdown]
# # Tokenizer

# %%
#tokenizing each word
w_token = word_tokenize(text)

# %%
#w_token = [word for word in w_token if not word in stopwords.words()]

# %%
#printing out all tokened words
for i in w_token:
    print(i)
# Out:
# So
# I
# gazed
# up
# at
# the
# tree
# with
# admiration
# and
# love
# in
# my
# eyes
# and
# said
# :
# “
# Ah
# ,
# my
# heart
# is
# smitten
# by
# this
# wonderful
# bird
# .
# If
# only
# I
# could
# hear
# her
# voice
# .
# I
# ’
# m
# sure
# that
# such
# a
# charming
# creature
# must
# sing
# most
# sweetly
# !
# If
# I
# could
# but
# hear
# one
# line
# of
# her
# song
# ,
# I
# would
# hail
# her
# as
# the
# Princess
# of
# The
# Forest
# !
# ”
# Now
# I
# could
# see
# my
# words
# had
# hit
# home
# .
# Swelling
# with
# pride
# ,
# Miss
# Crow
# puffed
# up
# her
# feathers
# and
# began
# to
# sing
# the
# most
# lovely
# music
# I
# have
# ever
# heard
# .

# %% [markdown]
# # POS

# %%
#pos tagging
tagged = nltk.pos_tag(w_token)

# %%
#printing out all tags
tagged
# Out:
# [('So', 'RB'),
#  ('I', 'PRP'),
#  ('gazed', 'VBD'),
#  ('up', 'RB'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('tree', 'NN'),
#  ('with', 'IN'),
#  ('admiration', 'NN'),
#  ('and', 'CC'),
#  ('love', 'NN'),
#  ('in', 'IN'),
#  ('my', 'PRP$'),
#  ('eyes', 'NNS'),
#  ('and', 'CC'),
#  ('said', 'VBD'),
#  (':', ':'),
#  ('“', 'NN'),
#  ('Ah', 'NNP'),
#  (',', ','),
#  ('my', 'PRP$'),
#  ('heart', 'NN'),
#  ('is', 'VBZ'),
#  ('smitten', 'VBN'),
#  ('by', 'IN'),
#  ('this', 'DT'),
#  ('wonderful', 'JJ'),
#  ('bird', 'NN'),
#  ('.', '.'),
#  ('If', 'IN'),
#  ('only', 'RB'),
#  ('I', 'PRP'),
#  ('could', 'MD'),
#  ('hear', 'VB'),
#  ('her', 'PRP$'),
#  ('voice', 'NN'),
#  ('.', '.'),
#  ('I', 'PRP'),
#  ('’', 'VBP'),
#  ('m', 'JJ'),
#  ('sure', 'JJ'),
#  ('that', 'IN'),
#  ('such', 'PDT'),
#  ('a', 'DT'),
#  ('charming', 'JJ'),
#  ('creature', 'NN'),
#  ('must', 'MD'),
#  ('sing', 'VB'),
#  ('most', 'RBS'),
#  ('sweetly', 'RB'),
#  ('!', '.'),
#  ('If', 'IN'),
#  ('I', 'PRP'),
#  ('could', 'MD'),
#  ('but', 'CC'),
#  ('hear', 'VB'),
#  ('one', 'CD'),
#  ('line', 'NN'),
#  ('of', 'IN'),
#  ('her', 'PRP$'),
#  ('song', 'NN'),
#  (',', ','),
#  ('I', 'PRP'),
#  ('would', 'MD'),
#  ('hail', 'VB'),
#  ('her', 'PRP'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('Princess', 'NNP'),
#  ('of', 'IN'),
#  ('The', 'DT'),
#  ('Forest', 'NNP'),
#  ('!', '.'),
#  ('”', 'NN'),
#  ('Now', 'RB'),
#  ('I', 'PRP'),
#  ('could', 'MD'),
#  ('see', 'VB'),
#  ('my', 'PRP$'),
#  ('words', 'NNS'),
#  ('had', 'VBD'),
#  ('hit', 'VBN'),
#  ('home', 'NN'),
#  ('.', '.'),
#  ('Swelling', 'VBG'),
#  ('with', 'IN'),
#  ('pride', 'NN'),
#  (',', ','),
#  ('Miss', 'NNP'),
#  ('Crow', 'NNP'),
#  ('puffed', 'VBD'),
#  ('up', 'RP'),
#  ('her', 'PRP$'),
#  ('feathers', 'NNS'),
#  ('and', 'CC'),
#  ('began', 'VBD'),
#  ('to', 'TO'),
#  ('sing', 'VBG'),
#  ('the', 'DT'),
#  ('most', 'RBS'),
#  ('lovely', 'JJ'),
#  ('music', 'NN'),
#  ('I', 'PRP'),
#  ('have', 'VBP'),
#  ('ever', 'RB'),
#  ('heard', 'VBN'),
#  ('.', '.')]

# %% [markdown]
# # Stemming

# %%
#choosing a stemmer
lStem = LancasterStemmer()

#looping through tokens and printing out original word and stemmed word
for i in w_token:
    print('Original: {:>10}       Stem: {:>10}'.format(i,lStem.stem(i)))
# Out:
# Original:         So       Stem:         so
# Original:          I       Stem:          i
# Original:      gazed       Stem:        gaz
# Original:         up       Stem:         up
# Original:         at       Stem:         at
# Original:        the       Stem:        the
# Original:       tree       Stem:        tre
# Original:       with       Stem:       with
# Original: admiration       Stem:      admir
# Original:        and       Stem:        and
# Original:       love       Stem:        lov
# Original:         in       Stem:         in
# Original:         my       Stem:         my
# Original:       eyes       Stem:         ey
# Original:        and       Stem:        and
# Original:       said       Stem:       said
# Original:          :       Stem:          :
# Original:          “       Stem:          “
# Original:         Ah       Stem:         ah
# Original:          ,       Stem:          ,
# Original:         my       Stem:         my
# Original:      heart       Stem:      heart
# Original:         is       Stem:         is
# Original:    smitten       Stem:       smit
# Original:         by       Stem:         by
# Original:       this       Stem:        thi
# Original:  wonderful       Stem:       wond
# Original:       bird       Stem:       bird
# Original:          .       Stem:          .
# Original:         If       Stem:         if
# Original:       only       Stem:         on
# Original:          I       Stem:          i
# Original:      could       Stem:      could
# Original:       hear       Stem:       hear
# Original:        her       Stem:        her
# Original:      voice       Stem:       voic
# Original:          .       Stem:          .
# Original:          I       Stem:          i
# Original:          ’       Stem:          ’
# Original:          m       Stem:          m
# Original:       sure       Stem:        sur
# Original:       that       Stem:       that
# Original:       such       Stem:       such
# Original:          a       Stem:          a
# Original:   charming       Stem:      charm
# Original:   creature       Stem:        cre
# Original:       must       Stem:       must
# Original:       sing       Stem:       sing
# Original:       most       Stem:       most
# Original:    sweetly       Stem:      sweet
# Original:          !       Stem:          !
# Original:         If       Stem:         if
# Original:          I       Stem:          i
# Original:      could       Stem:      could
# Original:        but       Stem:        but
# Original:       hear       Stem:       hear
# Original:        one       Stem:         on
# Original:       line       Stem:        lin
# Original:         of       Stem:         of
# Original:        her       Stem:        her
# Original:       song       Stem:       song
# Original:          ,       Stem:          ,
# Original:          I       Stem:          i
# Original:      would       Stem:      would
# Original:       hail       Stem:       hail
# Original:        her       Stem:        her
# Original:         as       Stem:         as
# Original:        the       Stem:        the
# Original:   Princess       Stem:   princess
# Original:         of       Stem:         of
# Original:        The       Stem:        the
# Original:     Forest       Stem:     forest
# Original:          !       Stem:          !
# Original:          ”       Stem:          ”
# Original:        Now       Stem:        now
# Original:          I       Stem:          i
# Original:      could       Stem:      could
# Original:        see       Stem:        see
# Original:         my       Stem:         my
# Original:      words       Stem:       word
# Original:        had       Stem:        had
# Original:        hit       Stem:        hit
# Original:       home       Stem:        hom
# Original:          .       Stem:          .
# Original:   Swelling       Stem:       swel
# Original:       with       Stem:       with
# Original:      pride       Stem:       prid
# Original:          ,       Stem:          ,
# Original:       Miss       Stem:       miss
# Original:       Crow       Stem:       crow
# Original:     puffed       Stem:       puff
# Original:         up       Stem:         up
# Original:        her       Stem:        her
# Original:   feathers       Stem:      feath
# Original:        and       Stem:        and
# Original:      began       Stem:        beg
# Original:         to       Stem:         to
# Original:       sing       Stem:       sing
# Original:        the       Stem:        the
# Original:       most       Stem:       most
# Original:     lovely       Stem:        lov
# Original:      music       Stem:        mus
# Original:          I       Stem:          i
# Original:       have       Stem:        hav
# Original:       ever       Stem:         ev
# Original:      heard       Stem:      heard
# Original:          .       Stem:          .

# %% [markdown]
# # Lemmatization

# %%
#choosing lemmatizer
lemmatizer = WordNetLemmatizer()

#looping through tokens and printing out original word and lemmatized word
for i in w_token:
    print('Original: {:>10}       Lem: {:>10}'.format(i,lemmatizer.lemmatize(i)))
# Out:
# Original:         So       Lem:         So
# Original:          I       Lem:          I
# Original:      gazed       Lem:      gazed
# Original:         up       Lem:         up
# Original:         at       Lem:         at
# Original:        the       Lem:        the
# Original:       tree       Lem:       tree
# Original:       with       Lem:       with
# Original: admiration       Lem: admiration
# Original:        and       Lem:        and
# Original:       love       Lem:       love
# Original:         in       Lem:         in
# Original:         my       Lem:         my
# Original:       eyes       Lem:        eye
# Original:        and       Lem:        and
# Original:       said       Lem:       said
# Original:          :       Lem:          :
# Original:          “       Lem:          “
# Original:         Ah       Lem:         Ah
# Original:          ,       Lem:          ,
# Original:         my       Lem:         my
# Original:      heart       Lem:      heart
# Original:         is       Lem:         is
# Original:    smitten       Lem:    smitten
# Original:         by       Lem:         by
# Original:       this       Lem:       this
# Original:  wonderful       Lem:  wonderful
# Original:       bird       Lem:       bird
# Original:          .       Lem:          .
# Original:         If       Lem:         If
# Original:       only       Lem:       only
# Original:          I       Lem:          I
# Original:      could       Lem:      could
# Original:       hear       Lem:       hear
# Original:        her       Lem:        her
# Original:      voice       Lem:      voice
# Original:          .       Lem:          .
# Original:          I       Lem:          I
# Original:          ’       Lem:          ’
# Original:          m       Lem:          m
# Original:       sure       Lem:       sure
# Original:       that       Lem:       that
# Original:       such       Lem:       such
# Original:          a       Lem:          a
# Original:   charming       Lem:   charming
# Original:   creature       Lem:   creature
# Original:       must       Lem:       must
# Original:       sing       Lem:       sing
# Original:       most       Lem:       most
# Original:    sweetly       Lem:    sweetly
# Original:          !       Lem:          !
# Original:         If       Lem:         If
# Original:          I       Lem:          I
# Original:      could       Lem:      could
# Original:        but       Lem:        but
# Original:       hear       Lem:       hear
# Original:        one       Lem:        one
# Original:       line       Lem:       line
# Original:         of       Lem:         of
# Original:        her       Lem:        her
# Original:       song       Lem:       song
# Original:          ,       Lem:          ,
# Original:          I       Lem:          I
# Original:      would       Lem:      would
# Original:       hail       Lem:       hail
# Original:        her       Lem:        her
# Original:         as       Lem:          a
# Original:        the       Lem:        the
# Original:   Princess       Lem:   Princess
# Original:         of       Lem:         of
# Original:        The       Lem:        The
# Original:     Forest       Lem:     Forest
# Original:          !       Lem:          !
# Original:          ”       Lem:          ”
# Original:        Now       Lem:        Now
# Original:          I       Lem:          I
# Original:      could       Lem:      could
# Original:        see       Lem:        see
# Original:         my       Lem:         my
# Original:      words       Lem:       word
# Original:        had       Lem:        had
# Original:        hit       Lem:        hit
# Original:       home       Lem:       home
# Original:          .       Lem:          .
# Original:   Swelling       Lem:   Swelling
# Original:       with       Lem:       with
# Original:      pride       Lem:      pride
# Original:          ,       Lem:          ,
# Original:       Miss       Lem:       Miss
# Original:       Crow       Lem:       Crow
# Original:     puffed       Lem:     puffed
# Original:         up       Lem:         up
# Original:        her       Lem:        her
# Original:   feathers       Lem:    feather
# Original:        and       Lem:        and
# Original:      began       Lem:      began
# Original:         to       Lem:         to
# Original:       sing       Lem:       sing
# Original:        the       Lem:        the
# Original:       most       Lem:       most
# Original:     lovely       Lem:     lovely
# Original:      music       Lem:      music
# Original:          I       Lem:          I
# Original:       have       Lem:       have
# Original:       ever       Lem:       ever
# Original:      heard       Lem:      heard
# Original:          .       Lem:          .

# %% [markdown]
# # NER

# %%
print(ne_chunk(pos_tag(wordpunct_tokenize(text))))
# Out:
# (S
#   So/RB
#   I/PRP
#   gazed/VBD
#   up/RB
#   at/IN
#   the/DT
#   tree/NN
#   with/IN
#   admiration/NN
#   and/CC
#   love/NN
#   in/IN
#   my/PRP$
#   eyes/NNS
#   and/CC
#   said/VBD
#   :/:
#   “/NN
#   Ah/NNP
#   ,/,
#   my/PRP$
#   heart/NN
#   is/VBZ
#   smitten/VBN
#   by/IN
#   this/DT
#   wonderful/JJ
#   bird/NN
#   ./.
#   If/IN
#   only/RB
#   I/PRP
#   could/MD
#   hear/VB
#   her/PRP$
#   voice/NN
#   ./.
#   I/PRP
#   ’/VBP
#   m/JJ
#   sure/JJ
#   that/IN
#   such/PDT
#   a/DT
#   charming/JJ
#   creature/NN
#   must/MD
#   sing/VB
#   most/RBS
#   sweetly/RB
#   !/.
#   If/IN
#   I/PRP
#   could/MD
#   but/CC
#   hear/VB
#   one/CD
#   line/NN
#   of/IN
#   her/PRP$
#   song/NN
#   ,/,
#   I/PRP
#   would/MD
#   hail/VB
#   her/PRP
#   as/IN
#   the/DT
#   (ORGANIZATION Princess/NNP)
#   of/IN
#   The/DT
#   (ORGANIZATION Forest/NNP)
#   !”/NN
#   Now/RB
#   I/PRP
#   could/MD
#   see/VB
#   my/PRP$
#   words/NNS
#   had/VBD
#   hit/VBN
#   home/NN
#   ./.
#   Swelling/VBG
#   with/IN
#   pride/NN
#   ,/,
#   (PERSON Miss/NNP Crow/NNP)
#   puffed/VBD
#   up/RP
#   her/PRP$
#   feathers/NNS
#   and/CC
#   began/VBD
#   to/TO
#   sing/VBG
#   the/DT
#   most/RBS
#   lovely/JJ
#   music/NN
#   I/PRP
#   have/VBP
#   ever/RB
#   heard/VBN
#   ./.)

# %% [markdown]
# # Trigram

# %%
#setting n-gram value
n = 3
trigram = ngrams(text.split(), n)

#printing all trigrams
for grams in trigram:
  print(grams)
# Out:
# ('So', 'I', 'gazed')
# ('I', 'gazed', 'up')
# ('gazed', 'up', 'at')
# ('up', 'at', 'the')
# ('at', 'the', 'tree')
# ('the', 'tree', 'with')
# ('tree', 'with', 'admiration')
# ('with', 'admiration', 'and')
# ('admiration', 'and', 'love')
# ('and', 'love', 'in')
# ('love', 'in', 'my')
# ('in', 'my', 'eyes')
# ('my', 'eyes', 'and')
# ('eyes', 'and', 'said:')
# ('and', 'said:', '“Ah,')
# ('said:', '“Ah,', 'my')
# ('“Ah,', 'my', 'heart')
# ('my', 'heart', 'is')
# ('heart', 'is', 'smitten')
# ('is', 'smitten', 'by')
# ('smitten', 'by', 'this')
# ('by', 'this', 'wonderful')
# ('this', 'wonderful', 'bird.')
# ('wonderful', 'bird.', 'If')
# ('bird.', 'If', 'only')
# ('If', 'only', 'I')
# ('only', 'I', 'could')
# ('I', 'could', 'hear')
# ('could', 'hear', 'her')
# ('hear', 'her', 'voice.')
# ('her', 'voice.', 'I’m')
# ('voice.', 'I’m', 'sure')
# ('I’m', 'sure', 'that')
# ('sure', 'that', 'such')
# ('that', 'such', 'a')
# ('such', 'a', 'charming')
# ('a', 'charming', 'creature')
# ('charming', 'creature', 'must')
# ('creature', 'must', 'sing')
# ('must', 'sing', 'most')
# ('sing', 'most', 'sweetly!')
# ('most', 'sweetly!', 'If')
# ('sweetly!', 'If', 'I')
# ('If', 'I', 'could')
# ('I', 'could', 'but')
# ('could', 'but', 'hear')
# ('but', 'hear', 'one')
# ('hear', 'one', 'line')
# ('one', 'line', 'of')
# ('line', 'of', 'her')
# ('of', 'her', 'song,')
# ('her', 'song,', 'I')
# ('song,', 'I', 'would')
# ('I', 'would', 'hail')
# ('would', 'hail', 'her')
# ('hail', 'her', 'as')
# ('her', 'as', 'the')
# ('as', 'the', 'Princess')
# ('the', 'Princess', 'of')
# ('Princess', 'of', 'The')
# ('of', 'The', 'Forest!”Now')
# ('The', 'Forest!”Now', 'I')
# ('Forest!”Now', 'I', 'could')
# ('I', 'could', 'see')
# ('could', 'see', 'my')
# ('see', 'my', 'words')
# ('my', 'words', 'had')
# ('words', 'had', 'hit')
# ('had', 'hit', 'home.')
# ('hit', 'home.', 'Swelling')
# ('home.', 'Swelling', 'with')
# ('Swelling', 'with', 'pride,')
# ('with', 'pride,', 'Miss')
# ('pride,', 'Miss', 'Crow')
# ('Miss', 'Crow', 'puffed')
# ('Crow', 'puffed', 'up')
# ('puffed', 'up', 'her')
# ('up', 'her', 'feathers')
# ('her', 'feathers', 'and')
# ('feathers', 'and', 'began')
# ('and', 'began', 'to')
# ('began', 'to', 'sing')
# ('to', 'sing', 'the')
# ('sing', 'the', 'most')
# ('the', 'most', 'lovely')
# ('most', 'lovely', 'music')
# ('lovely', 'music', 'I')
# ('music', 'I', 'have')
# ('I', 'have', 'ever')
# ('have', 'ever', 'heard.')

# %%
#using all paragraphs for word frequencies
all_text = page[0].string + page[1].string + page[2].string + page[3].string + page[4].string + page[5].string + page[6].string + page[7].string + page[8].string + page[9].string + page[10].string

# %% [markdown]
# Plot code modified from here
# https://www.absentdata.com/python-graphs/python-word-frequency/

# %%
def word_frequency(sentence):
    # joins all the sentenses
    sentence =''.join(sentence)
    # creates tokens, creates lower class, removes numbers and lemmatizes the words
    new_tokens = word_tokenize(sentence)
    new_tokens = [t.lower() for t in new_tokens]
    new_tokens =[t for t in new_tokens if t not in stopwords.words()]
    new_tokens = [t for t in new_tokens if t.isalpha()]
    lemmatizer = WordNetLemmatizer()
    new_tokens =[lemmatizer.lemmatize(t) for t in new_tokens]
    #counts the words, pairs and trigrams
    counted = Counter(new_tokens)
    #creates 3 data frames and returns thems
    word_freq = pd.DataFrame(counted.items(),columns=['word','frequency']).sort_values(by='frequency',ascending=False)
    return word_freq

# %%
data = word_frequency(all_text)

# %%
#checking until frequency is 1 word
data.head(42)
# Out:
#           word  frequency
# 47        miss          7
# 48        crow          7
# 99       could          5
# 69        beak          4
# 40       voice          3
# 3          eat          3
# 26      cheese          3
# 8          say          3
# 24        even          3
# 38        bird          3
# 15        ever          3
# 62      looked          2
# 41   wonderful          2
# 93    charming          2
# 49        fine          2
# 51     morning          2
# 123       sing          2
# 121       hear          2
# 97        sure          2
# 63        tree          2
# 89         eye          2
# 111       word          2
# 75          go          2
# 107        see          2
# 80        said          2
# 82      lovely          2
# 104    feather          2
# 66     looking          2
# 94    creature          2
# 18     chicken          2
# 27       today          2
# 19        wing          2
# 21      people          2
# 22        know          2
# 11      stolen          2
# 9          fox          2
# 7        would          2
# 25       piece          2
# 16        nice          2
# 2         like          2
# 4         best          2
# 102   wondrous          1

# %%
#plot frequencies
sns.set(rc={'figure.figsize':(12,12)})
sns.barplot(x='frequency',y='word',data=data.head(42))
# Out:
# <AxesSubplot:xlabel='frequency', ylabel='word'>
